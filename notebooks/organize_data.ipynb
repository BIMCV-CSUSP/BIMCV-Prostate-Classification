# %%
import pandas as pd

# %%
df = pd.read_csv('Files/data_with_splits_dep_disjoint.csv')

# %%
df['split'].value_counts()
# Out:
# split
# train    3675
# test      581
# val       404
# Name: count, dtype: int64

# %% [markdown]
# # Get patients for Interpretability

# %%
df_mids = pd.read_csv('Files/reports_val_csPC.csv')
